# %% [markdown]
# # <u>BeautifulSoup</u>
# Activity
#
# From Quotes, extract all quotes & authors from all pages with the life tag.

# %%
# import os
# os.makedirs("scraped_data", exist_ok=True)

# %%
import requests
from bs4 import BeautifulSoup

# %%
# Fetch data & store it

URL = "https://quotes.toscrape.com/page/1/"
page_count = 1

while True:
    URL = f"https://quotes.toscrape.com/page/{page_count}/"
    res = requests.get(URL)

    soup = BeautifulSoup(res.text, "lxml")
    quotes = soup.select("div.quote")

    if not quotes:
        print("No valid pages anaymore..")
        break

    with open(f"scraped_data/quotes{page_count}.html", "w", encoding="utf-8") as f:
        f.write(res.text)
        print(f"Dwonloaded data from page {page_count}")

    page_count = page_count + 1
# Out:
# Dwonloaded data from page 1
# Dwonloaded data from page 2
# Dwonloaded data from page 3
# Dwonloaded data from page 4
# Dwonloaded data from page 5
# Dwonloaded data from page 6
# Dwonloaded data from page 7
# Dwonloaded data from page 8
# Dwonloaded data from page 9
# Dwonloaded data from page 10
# No valid pages anaymore..

# %%
# Extract useful info - page1

with open("scraped_data/quotes1.html", "r", encoding="utf-8") as f:
    html_content = f.read()

soup = BeautifulSoup(html_content, "lxml")

# %%
all_quotes = soup.select("div.quote")
life_quotes = []

for q in all_quotes:
    all_tags = []

    for tag in q.select(".tags .tag"):
        all_tags.append(tag.get_text())

    if "life" in all_tags:
        text = q.select_one("span.text").get_text()
        author = q.select_one("small.author").get_text()
        life_quotes.append([text, author])

print(life_quotes)
# Out:
# [['“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”', 'Albert Einstein'], ['“It is better to be hated for what you are than to be loved for what you are not.”', 'André Gide']]
