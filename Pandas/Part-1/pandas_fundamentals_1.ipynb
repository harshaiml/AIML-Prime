# %% [markdown]
# ## <u>Data Science</u>
# Steps Involved
# 1. Define the program
# 2. Data Collection
# 3. EDA
# 4. Data Cleaning & Pre-processing
# 5. Feature Engineering
# 6. Modling
# 7. Evaluation
# 8. Deployment
