# %% [markdown]
# # <u>Data Collection</u>
# ### <i>Sources</i>
# - <u>Databases -</u> SQL (MySQL, PostgreSQL etc.), NoSQL databases (MongoDB etc.)
# - <u>Public Datasets -</u> Kaggle, UCI ML Repo etc.
# - <u>APIs -</u> Twitter API, Stock API, Weather API etc.
# - <u>Web Scraping -</u> HTML pages, blogs/articles, social media pages etc.
# - <u>Sensors & Devices -</u> IOT devices, health wearables etc.
# - <u>Surveys & Forms -</u> costomer satisfaction, feedback etc.
# - <u>System Generated -</u> logs, video feeds, synthetic data etc.
