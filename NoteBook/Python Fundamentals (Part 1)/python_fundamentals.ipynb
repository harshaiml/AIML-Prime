# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello \nworld", "with python")
# Out:
# Hello
# world with python

# %%
name = "Harsh"
age = 6
PI = 3.14

print("My name is",name)
# Out:
# My name is Harsh

# %%
name = "Harsh"
age = 28
PI = 3.14

print("My age is: ", age-4)
# Out:
# My age is:  24

# %%
name = "Harsh"
age = 6
PI = 3.14

print("My age is: ", age*4)
# Out:
# My age is:  24

# %%
_name = "Harsh"
_age = 24
_PI = 3.14

print(_name, _age, _PI)
# Out:
# Harsh 24 3.14

# %% [markdown]
# ### Data Type
# - Integer
# - String
# - Flot
# - Boolean
# - None

# %%
name = "Harsh"
age = 24
PI = 3.14

print(type(name))
# Out:
# <class 'str'>

# %%
name = "Harsh"
age = 24
PI = 3.14

print(type(age))
# Out:
# <class 'int'>

# %%
name = "Harsh"
age = 24
PI = 3.14

print(type(PI))
# Out:
# <class 'float'>

# %%
name = "Harsh"
age = 24
PI = 3.14

num = 2
isPrime = True

print(type(isPrime))
# Out:
# <class 'bool'>

# %%
name = "Harsh"
age = 24
PI = 3.14

num = 2
isPrime = False

print(type(isPrime))
# Out:
# <class 'bool'>

# %%
name = "Harsh"
age = 24
PI = 3.14

num = 2
isPrime = None

print(type(isPrime))
# Out:
# <class 'NoneType'>

# %% [markdown]
# ### Keywords

# %%
# We can't use this words as a variables
# ==========================================================

# False         # def        # in          # while
# None          # del        # is          # with
# True          # elif       # lambda      # yield
# and           # else       # match       # case
# as            # except     # nonlocal
# assert        # finally    # not
# async         # for        # or
# await         # from       # pass
# break         # global     # raise
# class         # if         # return
# continue      # import     # try

# %%
name = "Harsh"
age = 24
PI = 3.14

num = 2
isPrime = True

print(type(isPrime))
# Out:
# <class 'bool'>

# %%
# This is comment

# %%
# This is a multi-line comments

"""
name = "Harsh"
age = 24
PI = 3.14

num = 2
isPrime = True

print(type(isPrime))

"""
# Out:
# '\nname = "Harsh"\nage = 24\nPI = 3.14\n\nnum = 2\nisPrime = True\n\nprint(type(isPrime))\n\n'

# %% [markdown]
# ### Style Guide

# %%
# Style Guide

tot_price = 100           # snake_case
totPrice = 100            # camelCase
TotPrice = 100            # PascalCase

# %%
tot_price = 100
full_name = "Harsh Vardhan Kushwaha"

# %%
a = 5
b = 10

sum = a + b
print(sum)
# Out:
# 15

# %% [markdown]
# ## Operators
# - Arithmetic
# - Relational / Comparison
# - Assignment
# - Logical

# %% [markdown]
# Arithmetic Operators

# %%
# Arithmetic Operators

a = 10
b = 5

print(a+b)           # Addition
print(a-b)           # Subtraction
print(a*b)           # Multiplication
print(a/b)           # Devesion
print(a%b)           # Modulo
print(a**b)          # Power
# Out:
# 15
# 5
# 50
# 2.0
# 0
# 100000

# %% [markdown]
# Relational / Comparison Operators

# %%
# Relational / Comparison Operators

a = 10
b = 5
print(a < b)
# Out:
# False

# %%
# Relational / Comparison Operators

a = 10
b = 5
print(a > b)
# Out:
# True

# %%
# Relational / Comparison Operators

a = 10
b = 10
print(a != b)
# Out:
# False

# %%
# Relational / Comparison Operators

a = 10
b = 5
print(a != b)
# Out:
# True

# %%
# Relational / Comparison Operators

a = 10
b = 5
print(a >= b)
# Out:
# True

# %%
# Assignment Operators

a = 10
a = a + 5
print(a)
# Out:
# 15

# %%
# Assignment Operators

a = 10
a += 5
print(a)
# Out:
# 15

# %%
# Assignment Operators

a = 10
a -= 5
print(a)
# Out:
# 5

# %%
# Assignment Operators

a = 10
a *= 5
print(a)
# Out:
# 50

# %%
# Assignment Operators

a = 10
a /= 5
print(a)
# Out:
# 2.0

# %%
# Logical Operators

var = False
print(not var)   # True
# Out:
# True

# %%
# Logical Operators

var = False
print(not (5 > 8))   # True
# Out:
# True

# %%
# Logical Operators

var = False
print(not var)
# Out:
# True

# %%
# Logical Operators

var = False
print((5 > 3) and (3 > 2))
# Out:
# True

# %%
# Logical Operators

var = False
print((5 > 3) or (3 > 8))
# Out:
# True

# %%
# Logical Operators

var = False
print((5 > 13) and (3 > 8))
# Out:
# False

# %%
x = 3
x += 5
print(x)
# Out:
# 8

# %% [markdown]
# ## Operator Precedence

# %%
# ()
# **
# *, /, %
# +, -
# ==, !=, >, >=, <, <=
# not
# and
# or

# %% [markdown]
# ## Type Conversion

# %%
# Type Conversion

a = 10
b = 5
print(a / 5)
# Out:
# 2.0

# %%
# Type Conversion

a = 10
a = 5
print(type(a / 5))
# Out:
# <class 'float'>

# %%
# Type Conversion

ans = 5 + 10.0
print(ans)
print(type(ans))
# Out:
# 15.0
# <class 'float'>

# %%
# Type Conversion

ans = int(5 + 10.0)
print(ans)
print(type(ans))
# Out:
# 15
# <class 'int'>

# %%
# Type Conversion

ans1 = int(5 + 10.0)  #casting
ans2 = 5 + 10.0       # conversion

print(ans1, type(ans1))
print(ans2, type(ans2))
# Out:
# 15 <class 'int'>
# 15.0 <class 'float'>

# %%
# Type Conversion

val = int("123")
print(type(val))
# Out:
# <class 'int'>

# %%
# Type Conversion

val = bool(10)
print(val, type(val))
# Out:
# True <class 'bool'>

# %% [markdown]
# ## User input

# %%
# User input

a = input("Enter value of a: ")
print(a)
# Out:
# Python

# %%
# User input

username = input("Enter your name: ")
print("Welcome", username, "in AIML journey ")
# Out:
# Welcome Harsh in AIML journey

# %%
# Sum of 2 Numbers

num1 = int(input("Enter first number:"))
num2 = int(input("Enter second number: "))
sum = num1 + num2
print("Sum of the 2 number is:", sum)
# Out:
# Sum of the 2 number is: 100

# %%
# Sum of 2 numbers

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
sum = num1 + num2
print("Sum of the 2 numbers is:", sum)
# Out:
# Sum of the 2 numbers is: 100.0

# %%
# Calculate avrage of 2 numbers

num1 = int(input("Enter your first number: "))
num2 = int(input("Enter your second number: "))
avg = (num1 + num2) /2
print("Avrage of your 2 numbers is:", avg)
# Out:
# Avrage of your 2 numbers is: 50.0
