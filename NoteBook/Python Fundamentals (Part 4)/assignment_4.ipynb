# %% [markdown]
# # Python Fundamentals
#
# ## (Assignments)
#
# Assingnments Problems

# %% [markdown]
# <b>Concept:</b> Classes & Objects

# %% [markdown]
# **Q1.** Create a BankAccount class with attributes <u>account_number, owner_name, and blance.</u>
# Add **methods** to <u>deposit, withdraw, and check blance.</u>

# %%
class BankAccount:
    
    def __init__(self, account_number, owner_name, balance):
        self.account_number = account_number
        self.owner_name = owner_name
        self.balance = balance

    # Deposit method
    def deposit(self, amount):
        self.balance += amount
        print("Amount deposited:", amount)

    # Withdraw method
    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient balance!")
        else:
            self.balance -= amount
            print("Amount withdrawn:", amount)

    # Check balance
    def check_balance(self):
        print("Current balance:", self.balance)


# Object create
acc1 = BankAccount(101, "Harsh", 1000)

# Methods call
acc1.deposit(500)
acc1.withdraw(300)
acc1.check_balance()
# Out:
# Amount deposited: 500
# Amount withdrawn: 300
# Current balance: 1200

# %% [markdown]
# **Q2.** Create a class Book with the following attributes:
# - title
# - author
# - list of reviews
#
# And add methods to:
#
# - add a new review
# - count reviews
# - display all reviews

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
        self.reviews = [] # empty list

    # Add review
    def add_review(self, review):
        self.reviews.append(review)
        print("Review added!")

    # Count reviews
    def count_reviews(self):
        print("Total reviews:",len(self.reviews))

    # Display reviews
    def display_reviews(self):
        print("All Reviews:")
        for review in self.reviews:
            print("_",review)

# Object create
b1 = Book("Python Basics", "Harsh")

# Add reviews
b1.add_review("Very helpful book")
b1.add_review("Easy to understand")
b1.add_review("Greate for beginners")

# Show reviews
b1.display_reviews()

# Count reviews
b1.count_reviews()
# Out:
# Review added!
# Review added!
# Review added!
# All Reviews:
# _ Very helpful book
# _ Easy to understand
# _ Greate for beginners
# Total reviews: 3

# %% [markdown]
# **Q3.** Crete a class Student with **private** attributes _name, _roll_no, and _marks.
#
# Provide **getter** and **setter** methodds with validation (e.g., marks cannot be negative, roll number has to be between 1 & 100 & name cannot be empty).

# %%
class Student:
    
    def __init__(self, name, roll_no, marks):
        self.set_name(name)
        self.set_roll_no(roll_no)
        self.set_marks(marks)

    # Setter for name
    def set_name(self, name):
        if name != "":
            self.__name = name
        else:
            print("Invalid name!")

    # Getter for name
    def get_name(self):
        return self.__name

    # Setter for roll number
    def set_roll_no(self, roll_no):
        if 1 <= roll_no <= 100:
            self.__roll_no = roll_no
        else:
            print("Roll number must be between 1 and 100")

    # Getter for roll number
    def get_roll_no(self):
        return self.__roll_no

    # Setter for marks
    def set_marks(self, marks):
        if marks >= 0:
            self.__marks = marks
        else:
            print("Marks cannot be negative")

    # Getter for marks
    def get_marks(self):
        return self.__marks


# Object create
stu = Student("Harsh", 10, 85)

# Output
print(stu.get_name())
print(stu.get_roll_no())
print(stu.get_marks())
# Out:
# Harsh
# 10
# 85

# %% [markdown]
# **Q4.** Create a class Shape with a method area().
#
# Create subclasses Circle, Rectangle, and Triangle that **override** the area() method.

# %%
class Shape:
    def area(self):
        print("Area not define")

# Circle class
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        print("Area of Circle =", 3.14 * self.radius * self.radius)

# Rectangle class
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        print("Area of Rectangle =", self.length * self.width)


# Triangle class
class Triangle(Shape):
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def area(self):
        print("Area of Triangle =", 0.5 * self.base * self.height)

# Objects create
c = Circle(5)
r = Rectangle(4, 6)
t = Triangle(3, 8)

# Call area method
c.area()
r.area()
t.area()
# Out:
# Area of Circle = 78.5
# Area of Rectangle = 24
# Area of Triangle = 12.0

# %% [markdown]
# **Q5.** Create a **base** class Vehicle with attributes like brnad and model.
#
# Create two **subclasses Car and bike that add extra attributes - seats (in Car) & engine_cc (in Bike).

# %%
class Vehicle:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model


# Car class (child)
class Car(Vehicle):
    def __init__(self, brand, model, seats):
        super().__init__(brand, model)   # parent ka constructor call
        self.seats = seats


# Bike class (child)
class Bike(Vehicle):
    def __init__(self, brand, model, engine_cc):
        super().__init__(brand, model)   # parent ka constructor call
        self.engine_cc = engine_cc


# Objects create
c = Car("Toyota", "Fortuner", 7)
b = Bike("Yamaha", "R15", 155)

# Output
print(c.brand, c.model, c.seats)
print(b.brand, b.model, b.engine_cc)
# Out:
# Toyota Fortuner 7
# Yamaha R15 155

# %% [markdown]
# **Q6.** Create an **abstract** class Employee with an **abstract method** calculate_salary().
#
# Create subclasses Inter, FullTimeEmployee, and ContractEmployee that implement the method differently.

# %%
from abc import ABC, abstractmethod

# Abstract class
class Employee(ABC):

    @abstractmethod
    def calculate_salary(self):
        pass


# Intern class
class Intern(Employee):
    def __init__(self, stipend):
        self.stipend = stipend

    def calculate_salary(self):
        print("Intern Salary =", self.stipend)


# Full-time employee class
class FullTimeEmployee(Employee):
    def __init__(self, monthly_salary):
        self.monthly_salary = monthly_salary

    def calculate_salary(self):
        print("Full-Time Salary =", self.monthly_salary)


# Contract employee class
class ContractEmployee(Employee):
    def __init__(self, hours, rate_per_hour):
        self.hours = hours
        self.rate_per_hour = rate_per_hour

    def calculate_salary(self):
        print("Contract Salary =", self.hours * self.rate_per_hour)


# Objects create
i = Intern(10000)
f = FullTimeEmployee(50000)
c = ContractEmployee(40, 500)

# Output
i.calculate_salary()
f.calculate_salary()
c.calculate_salary()
# Out:
# Intern Salary = 10000
# Full-Time Salary = 50000
# Contract Salary = 20000

# %% [markdown]
# **Q7.** Create a class Person that allows the constructor to work with:
# - name only
# - name + age
# - name + age + address
#
# As direct constructor overloading (multiple constructors) are not allowed but we have to use **default parameters** to simulate constructor overloading.

# %%
class Person:
    def __init__(self, name, age=None, address=None):
        self.name = name
        self.age = age
        self.address = address

    def display(self):
        print("Name:", self.name)
        
        if self.age is not None:
            print("Age:", self.age)
        
        if self.address is not None:
            print("Address:", self.address)

        print("------------------")


# Different ways to create objects

p1 = Person("Harsh")
p2 = Person("Rahul", 20)
p3 = Person("Aman", 25, "Delhi")

p1.display()
p2.display()
p3.display()
# Out:
# Name: Harsh
# ------------------
# Name: Rahul
# Age: 20
# ------------------
# Name: Aman
# Age: 25
# Address: Delhi
# ------------------

# %% [markdown]
# **Q8.** Create a class Plyer with:
# - a class variable player_count
# - instance variables name and level
#
# Track how many players were created.

# %%
class Player:
    player_count = 0 # class variable

    def __init__(self, name, level):
        self.name = name  # instance variable
        self.level = level

        Player.player_count += 1    # increase count

    def display(self):
        print(f"Name: {self.name}, Level: {self.level}")

# Create objects
p1 = Player("Harsh", 8)
p2 = Player("Parasansha", 7)
p3 = Player("Meenashi", 4)
p4 = Player("Rahul", 3)

p1.display()
p2.display()
p3.display()
p4.display()
# Out:
# Name: Harsh, Level: 8
# Name: Parasansha, Level: 7
# Name: Meenashi, Level: 4
# Name: Rahul, Level: 3
