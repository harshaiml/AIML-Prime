# %% [markdown]
# ## <u>NumPy</u>
# designed for fast numerical computing

# %%
import numpy as np
import time

# %%
arr = np.array([1, 2, 3, 4, 5])
print(arr)
print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %% [markdown]
# ## <u>NumPy</u>
# Python List vs NumPy Arrays
#
# 1. NumPy arrays are faster (optimized in C)
# 2. NumPy stores data in continuous memory blocks
# 3. Uses less memory (optimized storage)
# 4. Built-in mathemetical functions
# 5. Supports dicrect vectorized operation

# %%
# Execution performance
size = 100_000_000

# Python list
py_list = list(range(size))
start = time.time()
sq_list = [x**2 for x in py_list]
end = time.time()
print(f"python list time = {end-start} seconds")

# NumPy arrays
np_arr = np.array(py_list)
start = time.time()
sq_array = np_arr ** 2
end = time.time()
print(f"numpy array time = {end-start} seconds")
# Out:
# python list time = 6.298170328140259 seconds
# numpy array time = 0.3302915096282959 seconds

# %%
import time

for i in range(3):
    start = time.time()
    sq_list = [x**2 for x in range(1_000_000)]
    print("Run", i+1, "Python:", time.time() - start)
# Out:
# Run 1 Python: 2.4500186443328857
# Run 2 Python: 0.07327008247375488
# Run 3 Python: 0.07053732872009277

# %%
import numpy as np

for i in range(3):
    start = time.time()
    arr = np.arange(1_000_000)
    sq = arr ** 2
    print("Run", i+1, "NumPy:", time.time() - start)
# Out:
# Run 1 NumPy: 0.007743120193481445
# Run 2 NumPy: 0.007837057113647461
# Run 3 NumPy: 0.0073812007904052734
